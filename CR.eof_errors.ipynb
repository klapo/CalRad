# %%
####################################################################################################
# CR.GrobsCompare.ipynb
# Karl Lapo July/2015
####################################################################################################
# EOF analysis of errors between ground observations and radiation products - uses dineof
####################################################################################################

# must insert this statement to render the plots within the notebook
# this is specific to the ipython notebook
# %matplotlib inline

## FLAGS for processing
flag_getdata = 0              # Load and process raw data (1)? Or load pre-processed data (0)?
    
## Import statements
# netcdf/numpy/xray
import numpy as np
from datetime import datetime, timedelta
import pandas as pd
import xray

# OS interaction
import sys, pickle, os

# import subplots function for plotting
import seaborn as sns
import matplotlib
from matplotlib.pyplot import subplots
import matplotlib.pyplot as plt
from matplotlib import cm
from mpl_toolkits.basemap import Basemap

## Directory listing
dir_data = '/Users/karllapo/gdrive/SnowHydrology/proj/CloudClimatology/data'
dir_print = '/Users/karllapo/gdrive/SnowHydrology/proj/CloudClimatology/Graphics'

# List of sub-directory names for each data set
dir_NLDAS = '/NLDAS'
dir_SYN = '/CERES_SYN'
dir_grobs = '/GroundObs'
dir_VIC = '/VIC_MTCLIM'
dir_MODIS = '/MODIS.IRRAD'

# Directory for basemap pickle files
dir_bmap = '/Users/karllapo/gdrive/SnowHydrology/proj/CloudClimatology/data/basemap'

# %%
####################################################################################################
# Functions
####################################################################################################

# %%
##### Basemap
def build_basemap(lon,lat,dir_bmap,bmap_name='basemap.pickle',rewrite=False):
    # Lat/Lon handling - map extent
    bmap_dict = {}
    bmap_dict['lat_i'] = np.min(lat)
    bmap_dict['lon_i'] = np.min(lon)
    bmap_dict['lat_j'] = np.max(lat)
    bmap_dict['lon_j'] = np.max(lon)
    
    bmap_dict['lat_mid'] = lat[np.round(lat.size/2)]
    bmap_dict['lon_mid'] = lon[np.round(lon.size/2)]
    
    bmap_dict['lat_labels'] = np.arange(np.round(bmap_dict['lat_i']), np.round(bmap_dict['lat_j']), 2)
    bmap_dict['lon_labels'] = np.arange(np.round(bmap_dict['lon_i']), np.round(bmap_dict['lon_j']), 2)
    
    os.chdir(dir_bmap)
    # Force rewriting basemap pickle file
    if rewrite:
        bmap = Basemap(llcrnrlon=bmap_dict['lon_i'],llcrnrlat=bmap_dict['lat_i'],\
                        urcrnrlon=bmap_dict['lon_j'],urcrnrlat=bmap_dict['lat_j'],\
                        rsphere=(6378137.00,6356752.3142),resolution='l',area_thresh=1000.,projection='lcc',\
                        lat_1=bmap_dict['lat_mid'],lon_0=bmap_dict['lon_mid'])
        pickle.dump(bmap,open(bmap_name,'wb'),-1)
    
    else:
        try:
            bmap = pickle.load(open(bmap_name,'rb'))
        except IOError as e:
            bmap = Basemap(llcrnrlon=bmap_dict['lon_i'],llcrnrlat=bmap_dict['lat_i'],\
                            urcrnrlon=bmap_dict['lon_j'],urcrnrlat=bmap_dict['lat_j'],\
                            rsphere=(6378137.00,6356752.3142),resolution='l',area_thresh=1000.,projection='lcc',\
                            lat_1=bmap_dict['lat_mid'],lon_0=bmap_dict['lon_mid'])
            pickle.dump(bmap,open(bmap_name,'wb'),-1)
    
    return bmap,bmap_dict

# %%
##### Discrete colorbar -- from Joe Hamman (https://github.com/jhamman/tonic/blob/master/tonic/plot_utils.py#L66-L94)
def cmap_discretize(cmap, n_colors=10):
    """Return discretized colormap.
    Parameters
    ----------
    cmap : str or colormap object
        Colormap to discretize.
    n_colors : int
        Number of discrete colors to divide `cmap` into.
    Returns
    ----------
    disc_cmap : LinearSegmentedColormap
        Discretized colormap.
    """
    try:
        cmap = cm.get_cmap(cmap)
    except:
        cmap = cm.get_cmap(eval(cmap))
    colors_i = np.concatenate((np.linspace(0, 1., n_colors), (0., 0., 0., 0.)))
    colors_rgba = cmap(colors_i)
    indices = np.linspace(0, 1., n_colors + 1)
    cdict = {}
    for ki, key in enumerate(('red', 'green', 'blue')):
        cdict[key] = [(indices[i], colors_rgba[i - 1, ki], colors_rgba[i, ki])
                      for i in range(n_colors + 1)]

    return matplotlib.colors.LinearSegmentedColormap(cmap.name + "_%d" % n_colors,
                                              cdict, 1024)

# %%
##### Iterative eof 
def naneof_BR2003(X):
    Xfunc = np.copy(X)
    if np.abs(np.nanmean(Xfunc)) > .001:
        # Remove nanmean of data
        dat_mean = np.nanmean(Xfunc)
        Xfunc[~np.isnan(Xfunc)] = Xfunc[~np.isnan(Xfunc)]-dat_mean
    else:
        dat_mean = 0
    ## Subset of data for validation, remove nans
    X0 = np.copy(Xfunc)
    idok_r,idok_c = np.nonzero(~np.isnan(Xfunc)) 
    id_val_r = idok_r[np.ceil(np.random.uniform(size=(np.floor(idok_r.shape[0]/50)))* \
                              idok_r.shape[0]).astype(int)-1] # validation subset (rows)
    id_val_c = idok_c[np.ceil(np.random.uniform(size=(np.floor(idok_c.shape[0]/50)))* \
                              idok_c.shape[0]).astype(int)-1] # validation subset (columns)
    
    X_val = Xfunc[id_val_r,id_val_c]
    mx_val = np.nansum(np.nansum(X_val**2))
    
    # remove validation subset from the data
    Xfunc[id_val_r,id_val_c] = np.nan;
    # Update index of non-nans
    idok_r,idok_c = np.nonzero(~np.isnan(Xfunc))
    # replace NaNs by zeros
    Xfunc[np.isnan(Xfunc)] = 0
    
    ## find out how many eigenfunctions to retain...
    Nit = 100
    tol = 1e-8
    err = np.empty(min(Xfunc.shape[1],20))*np.nan
    for Ne in np.arange(1,min(Xfunc.shape[1],20)):
        X1 = np.copy(Xfunc)
        for k in np.arange(2,Nit):
            # compute SVD (equivalent of economy method in matlab)
            U,D,V = np.linalg.svd(X1,full_matrices=False)
    
            # truncate and estimate "interpolated" D
            N = Ne
            Ut = U[:,0:N]
            Dt = D[0:N]
            Vt = V[0:N,:]
            Xa = np.dot(np.dot(Ut,np.diag(Dt)),Vt)
            Xa[idok_r,idok_c] = Xfunc[idok_r,idok_c] # restore real data
            X2 = np.copy(Xa)
    
            # termination criterium?
            dx=np.nansum((X2-X1)**2,axis=1)
            dx=dx[:,np.newaxis]
            mx=np.nansum(X2**2,axis=1)
            mx=mx[:,np.newaxis]
            dxex = np.linalg.lstsq(dx.T,mx.T)
            dxex = dxex[-1]
            if dxex < tol:
                print('Converged in '+str(k-1)+' iterations to the tolerance of '+str(tol))
                break
            X1 = np.copy(X2)
    
        # error?
        Xa = np.dot(np.dot(Ut,np.diag(Dt)),Vt)
        dx_val = np.nansum(np.nansum((Xa[id_val_r,id_val_c]-X_val)**2))
        err[Ne] = dx_val/mx_val
    
    ## Loop through again using the optimal number of eigenvalues only
    Nopt = np.flatnonzero(err == np.nanmin(err))
    
    X1 = np.copy(X0);
    # Subset of data for validation
    idok_r,idok_c = np.nonzero(~np.isnan(X1)) 
    X1[np.isnan(X1)] = 0
    for k in np.arange(2,Nit):
        # compute SVD (equivalent of economy method in matlab)
        U,D,V = np.linalg.svd(X1,full_matrices=False)#     N = Nopt;
        # truncate and estimate "interpolated" D
        N = Nopt
        Ut = U[:,0:N]
        Dt = D[0:N]
        Vt = V[0:N,:]
        Xa = np.dot(np.dot(Ut,np.diag(Dt)),Vt)
        Xa[idok_r,idok_c] = Xfunc[idok_r,idok_c] # restore real data
        X2 = np.copy(Xa)
        
        # termination criterium?
        dx=np.nansum((X2-X1)**2,axis=1)
        dx=dx[:,np.newaxis]
        mx=np.nansum(X2**2,axis=1)
        mx=mx[:,np.newaxis]
        dxex = np.linalg.lstsq(dx.T,mx.T)
        dxex = dxex[-1]
        if dxex < tol:
            print('Converged in '+str(k-1)+' iterations to the tolerance of '+str(tol))
            break
        X1 = np.copy(X2)
        
    # units in B
    B = np.dot(U,np.diag(D))  #the temporal modes
    amps = V # the spatial modes
    #the variance of the original temperature series
    orig_var = np.nanmean(X0**2) 
    #divide by the product of the original matrix size and by the variance
    variance = D**2/orig_var*100/(X0.shape[0]*X0.shape[1])
    
    return(B,amps,variance,dat_mean,Nopt,U,V,D)

# %%
####################################
## Read previously processed data ##
####################################
# ///// See CC.CA.StatisticsMaps.Master for details on creation of xray data 

###########
## NLDAS ##
os.chdir(dir_data+dir_NLDAS)
nldas = xray.open_dataset('CA.NLDAS.irrad.monthly.nc')
nldas = nldas.rename({'DLWRF_110_SFC':'LWdwn','DSWRF_110_SFC':'SWdwn'})

#########
## SYN ##
os.chdir(dir_data+dir_SYN)
syn = xray.open_dataset('CA.syn.irrad.monthly.nc')
syn.longitude.values = syn.longitude.values-360
syn.latitude.values = syn.latitude.values[::-1]
# Flip the syn array spatially
for d in np.arange(syn.time.size):
    syn.SWdwn.values[d-1,:,:] = np.flipud(syn.SWdwn.values[d-1,:,:])
    syn.LWdwn.values[d-1,:,:] = np.flipud(syn.LWdwn.values[d-1,:,:])

############
## MTCLIM ##
os.chdir(dir_data+dir_VIC)
mtclim = xray.open_dataset('CA.MTCLIM.irrad.monthly.nc')

#########################
## Ground Observations ##
os.chdir(dir_data+dir_grobs)
grobs = xray.open_dataset('CA.grobs.irrad.monthly.nc')
grobs.SWdwn.values[grobs.SWdwn.values == 0] = np.nan
grobs = grobs.rename({'lon':'longitude','lat':'latitude'})
grobs.longitude.values = -grobs.longitude.values

###########
## MODIS ##
os.chdir(dir_data+dir_MODIS)
modis = xray.open_dataset('CA.MODIS.irrad.monthly.nc')
modis.SWdwn.values[modis.SWdwn.values == 0] = np.nan
modis = modis.rename({'lon':'longitude','lat':'latitude'})

## List w/ all irradiance datasets
monthly_mean = {}
monthly_mean['syn'] = syn
monthly_mean['nldas'] = nldas
monthly_mean['mtclim'] = mtclim
monthly_mean['modis'] = modis
monthly_mean['grobs'] = grobs

# %%
####################################################
## Find grid point containing each ground station ##
####################################################
pr_names = ['mtclim','syn','nldas','modis']

# Station lat and lon
lon_stat = grobs.longitude.values
lat_stat = grobs.latitude.values

for pr in pr_names:        

    # lat/lon for product
    lon_rad = monthly_mean[pr].longitude.values
    lat_rad = monthly_mean[pr].latitude.values  
    # mesh
    lonm, latm = np.meshgrid(lon_rad,lat_rad)
    
    # Empty numpy array
    to_merge = np.empty((monthly_mean[pr].time.size,grobs.station.size))
    
    ## Product values in each grid containing station
    for stat in grobs.station.values:
        
        # Station index
        stat_ind = np.where(stat == grobs.station.values)
        # Distance to product grid lat-lon
        d = (latm-lat_stat[stat_ind])**2 + (lonm-lon_stat[stat_ind])**2
        # Index of closest product grid
        dind = np.where(d==np.amin(d))
        # Grad grid values at the station, put into xray dataset
        if (monthly_mean[pr].SWdwn.values[:,dind[0][0],dind[1][0]] == 0).all():
            to_merge[:,stat_ind[0]] = monthly_mean[pr].SWdwn.values[:,dind[0][0]+1,dind[1][0],np.newaxis]
        else:
            to_merge[:,stat_ind[0]] = monthly_mean[pr].SWdwn.values[:,dind[0][0],dind[1][0],np.newaxis]
        
    ## Merge products w/ grobs xray structure
    to_merge_ds = xray.Dataset({pr:(('time','station'),to_merge), \
                                    'time':monthly_mean[pr].time.values,\
                                    'station':grobs.station.values})
    grobs = grobs.merge(to_merge_ds)

# %% [raw]
# This analysis revealed that mtclim is missing on the order of 5 grid points, they are just zeros. The whole VIC/MTCLIM pre-processor just failed there apparently? Anyway, to work around this for now I am going to use the neighboring grid cell so that all the clustering, scatter plots, etc aren't entirely thrown off by the one zero-observed values point difference that occurs.

# %%
######## EOF of errors for each station
pr_names = ['mtclim','syn','nldas']
# Build basemap
lat = monthly_mean['mtclim'].latitude.values
lon = monthly_mean['mtclim'].longitude.values

bmp,bmd = build_basemap(lon,lat,dir_bmap,'CA.Domain.bmp.pickle',rewrite=True)
lat_labels = bmd['lat_labels']
lon_labels = bmd['lon_labels']

# Station lat and lon
lon_stat = grobs.longitude.values
lat_stat = grobs.latitude.values

# Discrete colormap
cmap_delta = cmap_discretize(cm.RdBu_r,11)

for pr in pr_names:
    print(pr)
    diff = grobs[pr].values[100:138,:]-grobs.SWdwn.values[100:138,:]
    B,amps,variance,dat_mean,Nopt,U,V,D = naneof_BR2003(diff)
    
    ## Plot Results
    fig = plt.figure(figsize=(15,5))
    gs = matplotlib.gridspec.GridSpec(1,4)
    ax = plt.subplot(gs[0])
    ax.plot(np.arange(1,11),variance[0:10])
    ax.set_title('eof variance explained')
    ax.set_ylabel('variance')
    ax.set_xlabel('eof #')
    for n in np.arange(0,3):
        ax = plt.subplot(gs[n+1])
        im = bmp.scatter(lon_stat,lat_stat,c=amps[n,:],s=75, linewidths=.25,latlon=True,cmap=cmap_delta,vmin=-.5,vmax=.5)
        ax.set_title('eof coef '+str(n+1))
    
        ## Format
        if n == 0:
            bmp.drawparallels(lat_labels,labels=[1,0,0,0])
        else:
            bmp.drawparallels(lat_labels)
        bmp.drawmeridians(lon_labels,labels=[0,0,0,1]) 
        
        # Colorbar
        if n == 2:
            cb = bmp.colorbar(im,"right", size="5%", pad='2%')
            cb.set_label('EOF (?)', fontsize=12)  
    
        # political boundaries.
        bmp.drawstates()
        bmp.drawcoastlines()
        bmp.drawcounties()

    fig.tight_layout()
    
#     os.chdir(dir_print)
#     fname = 'eof_errors.'+pr+'.png'
#     fig.savefig(fname)
#     plt.close(fig)
# Out:
# mtclim
# Converged in 36 iterations to the tolerance of 1e-08
# syn
# Converged in 41 iterations to the tolerance of 1e-08
# nldas

# %% [raw]
# Features: Correlation between errors at east of crest stations and stations on the western edge of the valley. Scattered errors within valley.
#
# Central valley errors mode appears to be one of the more significant modes (eof 2 for syn, eof 3 for nldas) but not for mtclim

# %%
######## EOF of SWdwn -- by network
pr_names = ['mtclim','syn','nldas']
# Build basemap
lat = monthly_mean['mtclim'].latitude.values
lon = monthly_mean['mtclim'].longitude.values

bmp,bmd = build_basemap(lon,lat,dir_bmap,'CA.Domain.bmp.pickle',rewrite=True)
lat_labels = bmd['lat_labels']
lon_labels = bmd['lon_labels']

cmap_delta = cmap_discretize(cm.RdBu_r,11)

network = ['CDWR','CIMIS_IPM']

for net in network:
    print(net)
    # Station lat and lon
    sub_set = grobs.swap_dims({'station':'network'}).sel(network=net).SWdwn.values[50:138,:]
    lon_stat = grobs.swap_dims({'station':'network'}).sel(network=net).longitude.values
    lat_stat = grobs.swap_dims({'station':'network'}).sel(network=net).latitude.values
    B,amps,variance,dat_mean,Nopt,U,V,D = naneof_BR2003(sub_set)
    
    ## Plot Results
    fig = plt.figure(figsize=(15,5))
    gs = matplotlib.gridspec.GridSpec(1,4)
    ax = plt.subplot(gs[0])
    ax.plot(np.arange(1,11),variance[0:10])
    ax.set_title('eof variance explained')
    ax.set_ylabel('variance')
    ax.set_xlabel('eof #')
    for n in np.arange(0,3):
        ax = plt.subplot(gs[n+1])
        im = bmp.scatter(lon_stat,lat_stat,c=amps[n,:],s=75, linewidths=.25,latlon=True,cmap=cm.RdBu,vmin=-.5,vmax=.5)
        ax.set_title('eof coef '+str(n+1))
        
        ## Format
        if n == 0:
            bmp.drawparallels(lat_labels,labels=[1,0,0,0])
        else:
            bmp.drawparallels(lat_labels)
        bmp.drawmeridians(lon_labels,labels=[0,0,0,1]) 
    
        if n == 2:
            cb = bmp.colorbar(im,"right", size="5%", pad='2%')
            cb.set_label('EOF (?)', fontsize=12)    
        
        # political boundaries.
        bmp.drawstates()
        bmp.drawcoastlines()
        bmp.drawcounties()
    
    fig.tight_layout()
    os.chdir(dir_print)
    fname = 'eof_swdwn.GroubyNetwork.'+net+'.png'
    fig.savefig(fname)
    plt.close(fig)
# Out:
# CDWR
# CIMIS_IPM

# %% [raw]
# Important lesson in making these graphs, include fixed colorscale for correlations, otherwise I'm prone to interpret meaningless signals that are actually just differences in color scale between plots.
#
# Some stations have zero correlation because they are just nan's throughout the entire period. May need to make eof method smarter by just dropping those from the analysis.
#
# 07/14/15 -- Did more stringent formatting of monthly observed values (e.g., removing stations outside the domain). Fixed many of the weird features showing up. Stations that do not correlate well correspond to those that don't have observations during most of the study period. All positive eof values for most other stations.

# %%
## index of stations that behave differently
eof_ind = np.nonzero(amps[0,:] < .06)
print(eof_ind)
plt.plot(np.squeeze(grobs.SWdwn.values),'k')
plt.plot(np.squeeze(grobs.SWdwn.values[:,eof_ind]),'r')
plt.figure()
plt.plot(amps[0,:])
plt.figure()
plt.plot(variance)
# Out:
# (array([41, 45, 47, 52, 53]),)

# %%
######## EOF of SWdwn -- identify bad stations?
pr_names = ['syn']
# pr_names = ['mtclim','syn','nldas']

# Build basemap
lat = monthly_mean['mtclim'].latitude.values
lon = monthly_mean['mtclim'].longitude.values

bmp,bmd = build_basemap(lon,lat,dir_bmap,'CA.Domain.bmp.pickle',rewrite=True)
lat_labels = bmd['lat_labels']
lon_labels = bmd['lon_labels']

# Station lat and lon
lon_stat = grobs.longitude.values
lat_stat = grobs.latitude.values

subperiod = np.arange(100,138)

for pr in pr_names:
    print(pr)
    diff = grobs[pr].values[subperiod,:]-grobs.SWdwn.values[subperiod,:]
    B,amps,variance,dat_mean,Nopt,U,V,D = naneof_BR2003(diff)
    
    ## Plot Results
    fig = plt.figure(figsize=(15,5))
    gs = matplotlib.gridspec.GridSpec(1,4)
    ax = plt.subplot(gs[0])
    ax.plot(np.arange(1,11),variance[0:10])
    ax.set_title('eof variance explained')
    ax.set_ylabel('variance')
    ax.set_xlabel('eof #')
    for n in np.arange(0,3):
        ax = plt.subplot(gs[n+1])
        im = bmp.scatter(lon_stat,lat_stat,c=amps[n,:],s=75, linewidths=.25,latlon=True,\
                         cmap=cm.RdBu,vmin=-.5,vmax=.5)
        ax.set_title('eof coef '+str(n+1))
    
        ## Format
        if n == 0:
            bmp.drawparallels(lat_labels,labels=[1,0,0,0])
        else:
            bmp.drawparallels(lat_labels)
        bmp.drawmeridians(lon_labels,labels=[0,0,0,1]) 
    
        if n == 2:
            cb = bmp.colorbar(im,"right", size="5%", pad='2%')
            cb.set_label('EOF (?)', fontsize=12)    
        # political boundaries.
        bmp.drawstates()
        bmp.drawcoastlines()
        bmp.drawcounties()

    fig.tight_layout()
    
#     os.chdir(dir_print)
#     fname = 'eof_errors.'+pr+'.png'
#     fig.savefig(fname)
#     plt.close(fig)
# Out:
# syn
# Converged in 40 iterations to the tolerance of 1e-08

# %%
## index of stations that behave differently
fig = plt.figure(figsize=(15,5))
gs = matplotlib.gridspec.GridSpec(1,4)
for n in np.arange(0,3):
    ax = plt.subplot(gs[0])
    plt.plot(amps[n,:])
    ax = plt.subplot(gs[n+1])
    eof_pos_ind = np.nonzero(amps[n,:] > 0)
    eof_neg_ind = np.nonzero(amps[n,:] < 0)
    eof_zero_ind = np.nonzero(amps[n,:] == 0)
    plt.plot(np.squeeze(diff[:,eof_pos_ind]),'r')
    plt.plot(np.squeeze(diff[:,eof_neg_ind]),'b')
    plt.plot(np.squeeze(diff[:,eof_zero_ind]),'k')

# %%
plt.plot(B[:,0])
plt.plot(B[:,1])
plt.plot(B[:,2])
print(amps.shape)
print(grobs)
# Out:
# (38, 73)
# <xray.Dataset>
# Dimensions:    (station: 73, time: 190)
# Coordinates:
#     network    (station) |S9 'CIMIS_IPM' 'CIMIS_IPM' 'CIMIS_IPM' 'CIMIS_IPM' ...
#     longitude  (station) float64 -119.5 -118.8 -121.1 -118.4 -120.0 -121.7 ...
#   * station    (station) |S19 'Alpaugh' 'ARVIN' 'Auburn' 'BISHOP' 'BLACKWLL' ...
#     elev       (station) float64 64.0 152.0 285.0 1.271e+03 215.0 14.0 287.0 ...
#   * time       (time) datetime64[ns] 2000-01-31 2000-02-29 2000-03-31 ...
#     latitude   (station) float64 35.87 35.2 38.88 37.35 35.65 37.93 39.27 ...
# Data variables:
#     SWdwn      (time, station) float64 nan nan nan nan nan nan nan nan nan ...
#     mtclim     (time, station) float64 100.2 107.7 78.98 100.6 103.8 76.25 ...
#     syn        (time, station) float64 nan nan nan nan nan nan nan nan nan ...
#     nldas      (time, station) float64 nan nan nan nan nan nan nan nan nan ...
#     modis      (time, station) float64 nan nan nan nan nan nan nan nan nan ...
